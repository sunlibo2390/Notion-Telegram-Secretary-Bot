# %%
import requests

TOKEN = "8096730072:AAHOhUyz8SBKgpTxxQl3FDvC5y0YW54NcWI"
CHAT_ID = 6604771431
# TEXT = "时间"

# url = f"https://api.telegram.org/bot{TOKEN}/sendMessage"
# response = requests.post(url, data={"chat_id": CHAT_ID, "text": TEXT})
# response.json()

# %%
import requests

url = f"https://api.telegram.org/bot{TOKEN}/getUpdates"
r = requests.get(url)
data = r.json()

for update in data["result"]:
    message = update.get("message", {})
    print(message.get("text"), "来自", message["from"]["username"])


for item in data['result']:
    print(item['message']['from']['first_name'])
    print(item['message']['date'])
    print(item['message']['text'])

# %%
url
# Out:
# 'https://api.telegram.org/bot8096730072:AAHOhUyz8SBKgpTxxQl3FDvC5y0YW54NcWI/getUpdates?offset=10'
